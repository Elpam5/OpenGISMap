# %%
import folium

# 主地图，设置了地图中心，地图缩放，使用天地图影像作为底图
map = folium.Map(location=[24.83041,102.8489],
                 tiles='http://t0.tianditu.gov.cn/img_w/wmts?SERVICE=WMTS&REQUEST=GetTile&VERSION=1.0.0&LAYER=img&STYLE=default&TILEMATRIXSET=w&FORMAT=tiles&TILEMATRIX={z}&TILEROW={y}&TILECOL={x}&tk=95478fb1c6e5ac392e34aa9389a83b81',
                 attr='天地图影像',
                 zoom_start=15)

# 定义了所用标记的样式，ico表示建筑，lake表示湖泊
ico = {"prefix": "fa",'color':'red','icon':'fa-building'}
lake = {"prefix": "fa",'color':'red','icon':'fa-water'}

# 先编写html代码，作为显示框架，再用IFrame嵌入窗体，最后将窗体作为popup参数传入Marker，得到点击弹出的窗体
# 3句代码为一组，表示了一个地点的窗体构建代码
# 图书馆
tsghtml="""
<!DOCTYPE html>
<html>
    <head>
        <meta charset="utf-8">
        <style>
            html{
                width: 320px;
                height: 280px;
            }
            body{
                margin: 0;
                padding: 0;
                width: 320px;
                height: 280px;
            }
            p{
                margin: 0;
            }
            .jieshao{
                width: 320px;
                height: 100px;
            }
            .tupian{
                width: 320px;
                height: 180px;
            }
            .biaoti{
                font-size: 18px;
                font-weight: bold;
            }
            .text{
                font-size: 16px;
                /* 开头缩进2字符 */
                text-indent: 2em;
            }
            img{
                height: 100%;
                width: 100%;
            }
        </style>
    </head>
    <body>
        <div class="jieshao">
            <p class="biaoti">图书馆</p>
            <p class="text">云南大学图书馆始建于1923年，是一座资源丰富、功能齐全、现代化、综合性、开放式、互动式、体验式的学习研究型图书馆。</p>
        </div>
        <div class="tupian">
            <img src="https://pic.imgdb.cn/item/6573f991c458853aef9511dd.jpg" alt="图书馆"> <!-- 图片路径 -->
        </div>
    </body>
</html>
"""
tsgirame = folium.IFrame(html=tsghtml,width=330,height=300)
tsgpop = folium.Popup(tsgirame,max_width=320)

#北门
bmhtml="""
<!DOCTYPE html>
<html>
    <head>
        <meta charset="utf-8">
        <style>
            html{
                width: 320px;
                height: 280px;
            }
            body{
                margin: 0;
                padding: 0;
                width: 320px;
                height: 280px;
            }
            p{
                margin: 0;
            }
            .jieshao{
                width: 320px;
                height: 100px;
            }
            .tupian{
                width: 320px;
                height: 180px;
            }
            .biaoti{
                font-size: 18px;
                font-weight: bold;
            }
            .text{
                font-size: 16px;
                /* 开头缩进2字符 */
                text-indent: 2em;
            }
            img{
                height: 100%;
                width: 100%;
            }
        </style>
    </head>
    <body>
        <div class="jieshao">
            <p class="biaoti">北门</p>
            <p class="text"></p>
        </div>
        <div class="tupian">
            <img src="https://pic.imgdb.cn/item/6573fb7ec458853aef9c4939.jpg" alt="北门"> <!-- 图片路径 -->
        </div>
    </body>
</html>
"""
bmirame = folium.IFrame(html=bmhtml,width=330,height=300)
bmpop = folium.Popup(bmirame,max_width=320)

# 明远楼
mylhtml="""
<!DOCTYPE html>
<html>
    <head>
        <meta charset="utf-8">
        <style>
            html{
                width: 320px;
                height: 280px;
            }
            body{
                margin: 0;
                padding: 0;
                width: 320px;
                height: 280px;
            }
            p{
                margin: 0;
            }
            .jieshao{
                width: 320px;
                height: 100px;
            }
            .tupian{
                width: 320px;
                height: 180px;
            }
            .biaoti{
                font-size: 18px;
                font-weight: bold;
            }
            .text{
                font-size: 16px;
                /* 开头缩进2字符 */
                text-indent: 2em;
            }
            img{
                height: 100%;
                width: 100%;
            }
        </style>
    </head>
    <body>
        <div class="jieshao">
            <p class="biaoti">明远楼</p>
            <p class="text"></p>
        </div>
        <div class="tupian">
            <img src="https://pic.imgdb.cn/item/6573fc16c458853aef9e61d7.webp" alt="明远楼"> <!-- 图片路径 -->
        </div>
    </body>
</html>
"""
mylirame = folium.IFrame(html=mylhtml,width=330,height=300)
mylpop = folium.Popup(mylirame,max_width=320)

#学生会堂
hthtml="""
<!DOCTYPE html>
<html>
    <head>
        <meta charset="utf-8">
        <style>
            html{
                width: 320px;
                height: 280px;
            }
            body{
                margin: 0;
                padding: 0;
                width: 320px;
                height: 280px;
            }
            p{
                margin: 0;
            }
            .jieshao{
                width: 320px;
                height: 100px;
            }
            .tupian{
                width: 320px;
                height: 180px;
            }
            .biaoti{
                font-size: 18px;
                font-weight: bold;
            }
            .text{
                font-size: 16px;
                /* 开头缩进2字符 */
                text-indent: 2em;
            }
            img{
                height: 100%;
                width: 100%;
            }
        </style>
    </head>
    <body>
        <div class="jieshao">
            <p class="biaoti">学生会堂</p>
            <p class="text"></p>
        </div>
        <div class="tupian">
            <img src="https://pic.imgdb.cn/item/6573fd21c458853aefa218c7.png" alt="学生会堂"> <!-- 图片路径 -->
        </div>
    </body>
</html>
"""
htiframe = folium.IFrame(html=hthtml,width=330,height=300)
htpop = folium.Popup(htiframe,max_width=320)

# 天文台
twthtml="""
<!DOCTYPE html>
<html>
    <head>
        <meta charset="utf-8">
        <style>
            html{
                width: 320px;
                height: 280px;
            }
            body{
                margin: 0;
                padding: 0;
                width: 320px;
                height: 280px;
            }
            p{
                margin: 0;
            }
            .jieshao{
                width: 320px;
                height: 100px;
            }
            .tupian{
                width: 320px;
                height: 180px;
            }
            .biaoti{
                font-size: 18px;
                font-weight: bold;
            }
            .text{
                font-size: 16px;
                /* 开头缩进2字符 */
                text-indent: 2em;
            }
            img{
                height: 100%;
                width: 100%;
            }
        </style>
    </head>
    <body>
        <div class="jieshao">
            <p class="biaoti">天文台</p>
            <p class="text"></p>
        </div>
        <div class="tupian">
            <img src="https://pic.imgdb.cn/item/6573fdb7c458853aefa42f33.webp" alt="天文台"> <!-- 图片路径 -->
        </div>
    </body>
</html>
"""
twtiframe = folium.IFrame(html=twthtml,width=330,height=300)
twtpop = folium.Popup(twtiframe,max_width=320)

# 泽湖
zehuhtml="""
<!DOCTYPE html>
<html>
    <head>
        <meta charset="utf-8">
        <style>
            html{
                width: 320px;
                height: 280px;
            }
            body{
                margin: 0;
                padding: 0;
                width: 320px;
                height: 280px;
            }
            p{
                margin: 0;
            }
            .jieshao{
                width: 320px;
                height: 100px;
            }
            .tupian{
                width: 320px;
                height: 180px;
            }
            .biaoti{
                font-size: 18px;
                font-weight: bold;
            }
            .text{
                font-size: 16px;
                /* 开头缩进2字符 */
                text-indent: 2em;
            }
            img{
                height: 100%;
                width: 100%;
            }
        </style>
    </head>
    <body>
        <div class="jieshao">
            <p class="biaoti">泽湖</p>
            <p class="text"></p>
        </div>
        <div class="tupian">
            <img src="https://pic.imgdb.cn/item/6573fe21c458853aefa5cefd.jpg" alt="泽湖"> <!-- 图片路径 -->
        </div>
    </body>
</html>
"""
zhiframe = folium.IFrame(html=zehuhtml,width=330,height=300)
zhpop = folium.Popup(zhiframe,max_width=320)

# 依次添加标记到地图，popup参数为弹出窗体，tooltip参数为鼠标悬停显示文字，icon参数为标记样式
tushuguan = folium.Marker([24.82744,102.84745],popup=tsgpop,tooltip='图书馆',icon=folium.Icon(**ico)).add_to(map)
mingyuanlou = folium.Marker([24.83198,102.84778],popup=mylpop,tooltip='明远楼',icon=folium.Icon(**ico)).add_to(map)
xueshenghuitang = folium.Marker([24.8295,102.84545],popup=htpop,tooltip='学生会堂',icon=folium.Icon(**ico)).add_to(map)
beimen = folium.Marker([24.83606,102.84628],popup=bmpop,tooltip='北门',icon=folium.Icon(**ico)).add_to(map)
tianwentai = folium.Marker([24.83067,102.84992],popup=twtpop,tooltip='天文台',icon=folium.Icon(**ico)).add_to(map)
zehu = folium.Marker([24.83455,102.84234],popup=zhpop,tooltip='泽湖',icon=folium.Icon(**lake)).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
